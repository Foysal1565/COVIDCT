# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications import InceptionV3, VGG19
from tensorflow.keras.applications.resnet50 import ResNet50

# %%
disease_types=['COVID', 'non-COVID']
data_dir = '/content/drive/MyDrive/ML/COVID_19_DATA/'
train_dir = os.path.join(data_dir)

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.head()
# Out:
#                      File  DiseaseID Disease Type
# 0   COVID/Covid (126).png          0        COVID
# 1   COVID/Covid (178).png          0        COVID
# 2  COVID/Covid (1249).png          0        COVID
# 3   COVID/Covid (169).png          0        COVID
# 4   COVID/Covid (123).png          0        COVID

# %%
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                             File  DiseaseID Disease Type
# 0          COVID/Covid (281).png          0        COVID
# 1           COVID/Covid (64).png          0        COVID
# 2  non-COVID/Non-Covid (542).png          1    non-COVID
# 3  non-COVID/Non-Covid (608).png          1    non-COVID
# 4          COVID/Covid (749).png          0        COVID

# %%
from google.colab import files as FILE
import os
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10)) 
train['Disease Type'].value_counts().plot(kind = "bar", color='purple')
plt.title('Frequency Histogram of Images', fontsize= 15)
plt.xlabel('Type of Image', fontsize=15)
plt.ylabel('Number of Images', fontsize=15)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.show()
plt.gcf()
plt.savefig('/content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/1.png',  dpi=300)

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('COVID', 5, 5)

# %%
# Displays first n images of class from training set
plot_defects('non-COVID', 5, 5)

# %%
IMAGE_SIZE = 120
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 2482it [10:52,  3.80it/s]
# Train Shape: (2482, 120, 120, 3)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=2)

# %%
BATCH_SIZE = 256

# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 15))
for i in range(3):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_types[np.argmax(Y_train[i])])

# %%
EPOCHS = 800
SIZE=120
N_ch=3

# %%
def build_in():
    inception = VGG19(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = inception(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
model = build_in()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('/content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5', verbose=1, save_best_only=True)
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)
# Fits the model on batches with real-time data augmentation
hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# 80150528/80134624 [==============================] - 0s 0us/step
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 120, 120, 3)]     0
#
#  conv2d (Conv2D)             (None, 120, 120, 3)       84
#
#  vgg19 (Functional)          (None, None, None, 512)   20024384
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  batch_normalization_2 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  root (Dense)                (None, 2)                 514
#
# =================================================================
# Total params: 20,293,014
# Trainable params: 20,290,454
# Non-trainable params: 2,560
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/800
#
# Epoch 00001: val_loss improved from inf to 0.68182, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 34s - loss: 1.2880 - accuracy: 0.5234 - val_loss: 0.6818 - val_accuracy: 0.6479 - lr: 0.0010 - 34s/epoch - 5s/step
# Epoch 2/800
#
# Epoch 00002: val_loss improved from 0.68182 to 0.67895, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 7s - loss: 1.2972 - accuracy: 0.5072 - val_loss: 0.6789 - val_accuracy: 0.5473 - lr: 0.0010 - 7s/epoch - 940ms/step
# Epoch 3/800
#
# Epoch 00003: val_loss improved from 0.67895 to 0.67549, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 6s - loss: 1.2230 - accuracy: 0.5188 - val_loss: 0.6755 - val_accuracy: 0.5473 - lr: 0.0010 - 6s/epoch - 928ms/step
# Epoch 4/800
#
# Epoch 00004: val_loss did not improve from 0.67549
# 7/7 - 6s - loss: 1.1929 - accuracy: 0.5263 - val_loss: 0.6762 - val_accuracy: 0.5493 - lr: 0.0010 - 6s/epoch - 844ms/step
# Epoch 5/800
#
# Epoch 00005: val_loss improved from 0.67549 to 0.67454, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 10s - loss: 1.1329 - accuracy: 0.5425 - val_loss: 0.6745 - val_accuracy: 0.5493 - lr: 0.0010 - 10s/epoch - 1s/step
# Epoch 6/800
#
# Epoch 00006: val_loss improved from 0.67454 to 0.66632, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 7s - loss: 1.1660 - accuracy: 0.5361 - val_loss: 0.6663 - val_accuracy: 0.5614 - lr: 0.0010 - 7s/epoch - 938ms/step
# Epoch 7/800
#
# Epoch 00007: val_loss improved from 0.66632 to 0.65644, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 7s - loss: 1.1355 - accuracy: 0.5350 - val_loss: 0.6564 - val_accuracy: 0.5654 - lr: 0.0010 - 7s/epoch - 934ms/step
# Epoch 8/800
#
# Epoch 00008: val_loss improved from 0.65644 to 0.63621, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 7s - loss: 1.0932 - accuracy: 0.5703 - val_loss: 0.6362 - val_accuracy: 0.5936 - lr: 0.0010 - 7s/epoch - 949ms/step
# Epoch 9/800
#
# Epoch 00009: val_loss did not improve from 0.63621
# 7/7 - 6s - loss: 1.0987 - accuracy: 0.5529 - val_loss: 0.6545 - val_accuracy: 0.5895 - lr: 0.0010 - 6s/epoch - 824ms/step
# Epoch 10/800
#
# Epoch 00010: val_loss did not improve from 0.63621
# 7/7 - 6s - loss: 1.0721 - accuracy: 0.5656 - val_loss: 0.6677 - val_accuracy: 0.5473 - lr: 0.0010 - 6s/epoch - 824ms/step
# Epoch 11/800
#
# Epoch 00011: val_loss did not improve from 0.63621
# 7/7 - 6s - loss: 1.1080 - accuracy: 0.5471 - val_loss: 0.7371 - val_accuracy: 0.5473 - lr: 0.0010 - 6s/epoch - 859ms/step
# Epoch 12/800
#
# Epoch 00012: val_loss did not improve from 0.63621
# 7/7 - 6s - loss: 1.0768 - accuracy: 0.5497 - val_loss: 0.6511 - val_accuracy: 0.6579 - lr: 0.0010 - 6s/epoch - 848ms/step
# Epoch 13/800
#
# Epoch 00013: val_loss improved from 0.63621 to 0.61054, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 8s - loss: 1.0026 - accuracy: 0.5680 - val_loss: 0.6105 - val_accuracy: 0.7042 - lr: 0.0010 - 8s/epoch - 1s/step
# Epoch 14/800
#
# Epoch 00014: val_loss improved from 0.61054 to 0.60031, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 7s - loss: 0.9335 - accuracy: 0.6044 - val_loss: 0.6003 - val_accuracy: 0.6962 - lr: 0.0010 - 7s/epoch - 954ms/step
# Epoch 15/800
#
# Epoch 00015: val_loss improved from 0.60031 to 0.59597, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 7s - loss: 0.9465 - accuracy: 0.5842 - val_loss: 0.5960 - val_accuracy: 0.6620 - lr: 0.0010 - 7s/epoch - 933ms/step
# Epoch 16/800
#
# Epoch 00016: val_loss improved from 0.59597 to 0.58099, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 7s - loss: 0.8884 - accuracy: 0.6084 - val_loss: 0.5810 - val_accuracy: 0.6922 - lr: 0.0010 - 7s/epoch - 956ms/step
# Epoch 17/800
#
# Epoch 00017: val_loss did not improve from 0.58099
# 7/7 - 6s - loss: 0.8749 - accuracy: 0.6217 - val_loss: 0.6334 - val_accuracy: 0.5473 - lr: 0.0010 - 6s/epoch - 838ms/step
# Epoch 18/800
#
# Epoch 00018: val_loss did not improve from 0.58099
# 7/7 - 6s - loss: 0.8237 - accuracy: 0.6339 - val_loss: 1.1777 - val_accuracy: 0.5473 - lr: 0.0010 - 6s/epoch - 860ms/step
# Epoch 19/800
#
# Epoch 00019: val_loss did not improve from 0.58099
# 7/7 - 6s - loss: 0.8181 - accuracy: 0.6512 - val_loss: 0.8689 - val_accuracy: 0.5473 - lr: 0.0010 - 6s/epoch - 873ms/step
# Epoch 20/800
#
# Epoch 00020: val_loss improved from 0.58099 to 0.56059, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 8s - loss: 0.8252 - accuracy: 0.6426 - val_loss: 0.5606 - val_accuracy: 0.7525 - lr: 0.0010 - 8s/epoch - 1s/step
# Epoch 21/800
#
# Epoch 00021: val_loss did not improve from 0.56059
# 7/7 - 6s - loss: 0.8114 - accuracy: 0.6356 - val_loss: 0.5700 - val_accuracy: 0.7002 - lr: 0.0010 - 6s/epoch - 822ms/step
# Epoch 22/800
#
# Epoch 00022: val_loss did not improve from 0.56059
# 7/7 - 6s - loss: 0.7980 - accuracy: 0.6385 - val_loss: 0.6766 - val_accuracy: 0.5594 - lr: 0.0010 - 6s/epoch - 848ms/step
# Epoch 23/800
#
# Epoch 00023: val_loss did not improve from 0.56059
# 7/7 - 6s - loss: 0.7350 - accuracy: 0.6611 - val_loss: 0.8310 - val_accuracy: 0.5010 - lr: 0.0010 - 6s/epoch - 867ms/step
# Epoch 24/800
#
# Epoch 00024: val_loss did not improve from 0.56059
# 7/7 - 6s - loss: 0.7678 - accuracy: 0.6663 - val_loss: 0.6066 - val_accuracy: 0.6378 - lr: 0.0010 - 6s/epoch - 842ms/step
# Epoch 25/800
#
# Epoch 00025: val_loss did not improve from 0.56059
# 7/7 - 6s - loss: 0.7086 - accuracy: 0.6796 - val_loss: 0.5925 - val_accuracy: 0.6700 - lr: 0.0010 - 6s/epoch - 814ms/step
# Epoch 26/800
#
# Epoch 00026: val_loss improved from 0.56059 to 0.42766, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 8s - loss: 0.6649 - accuracy: 0.7073 - val_loss: 0.4277 - val_accuracy: 0.7907 - lr: 0.0010 - 8s/epoch - 1s/step
# Epoch 27/800
#
# Epoch 00027: val_loss did not improve from 0.42766
# 7/7 - 6s - loss: 0.7055 - accuracy: 0.7131 - val_loss: 0.4862 - val_accuracy: 0.7626 - lr: 0.0010 - 6s/epoch - 836ms/step
# Epoch 28/800
#
# Epoch 00028: val_loss did not improve from 0.42766
# 7/7 - 6s - loss: 0.6913 - accuracy: 0.6969 - val_loss: 0.4970 - val_accuracy: 0.7626 - lr: 0.0010 - 6s/epoch - 822ms/step
# Epoch 29/800
#
# Epoch 00029: val_loss improved from 0.42766 to 0.41839, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 8s - loss: 0.6829 - accuracy: 0.7195 - val_loss: 0.4184 - val_accuracy: 0.8290 - lr: 0.0010 - 8s/epoch - 1s/step
# Epoch 30/800
#
# Epoch 00030: val_loss did not improve from 0.41839
# 7/7 - 6s - loss: 0.6390 - accuracy: 0.7247 - val_loss: 2.0050 - val_accuracy: 0.5473 - lr: 0.0010 - 6s/epoch - 828ms/step
# Epoch 31/800
#
# Epoch 00031: val_loss did not improve from 0.41839
# 7/7 - 6s - loss: 0.6732 - accuracy: 0.7193 - val_loss: 1.7981 - val_accuracy: 0.5473 - lr: 0.0010 - 6s/epoch - 851ms/step
# Epoch 32/800
#
# Epoch 00032: val_loss did not improve from 0.41839
# 7/7 - 6s - loss: 0.6280 - accuracy: 0.7316 - val_loss: 0.6380 - val_accuracy: 0.7082 - lr: 0.0010 - 6s/epoch - 856ms/step
# Epoch 33/800
#
# Epoch 00033: val_loss did not improve from 0.41839
# 7/7 - 6s - loss: 0.6705 - accuracy: 0.6969 - val_loss: 0.8509 - val_accuracy: 0.6177 - lr: 0.0010 - 6s/epoch - 821ms/step
# Epoch 34/800
#
# Epoch 00034: val_loss did not improve from 0.41839
# 7/7 - 6s - loss: 0.6306 - accuracy: 0.7321 - val_loss: 4.5143 - val_accuracy: 0.5473 - lr: 0.0010 - 6s/epoch - 837ms/step
# Epoch 35/800
#
# Epoch 00035: val_loss did not improve from 0.41839
# 7/7 - 6s - loss: 0.5938 - accuracy: 0.7432 - val_loss: 0.7708 - val_accuracy: 0.6660 - lr: 0.0010 - 6s/epoch - 824ms/step
# Epoch 36/800
#
# Epoch 00036: val_loss did not improve from 0.41839
# 7/7 - 6s - loss: 0.5836 - accuracy: 0.7472 - val_loss: 2.3761 - val_accuracy: 0.5473 - lr: 0.0010 - 6s/epoch - 852ms/step
# Epoch 37/800
#
# Epoch 00037: val_loss did not improve from 0.41839
# 7/7 - 6s - loss: 0.5499 - accuracy: 0.7727 - val_loss: 1.2407 - val_accuracy: 0.5654 - lr: 0.0010 - 6s/epoch - 835ms/step
# Epoch 38/800
#
# Epoch 00038: val_loss did not improve from 0.41839
# 7/7 - 6s - loss: 0.5491 - accuracy: 0.7577 - val_loss: 1.2514 - val_accuracy: 0.5895 - lr: 0.0010 - 6s/epoch - 826ms/step
# Epoch 39/800
#
# Epoch 00039: val_loss did not improve from 0.41839
# 7/7 - 6s - loss: 0.5812 - accuracy: 0.7478 - val_loss: 1.1157 - val_accuracy: 0.5594 - lr: 0.0010 - 6s/epoch - 840ms/step
# Epoch 40/800
#
# Epoch 00040: val_loss did not improve from 0.41839
# 7/7 - 6s - loss: 0.5364 - accuracy: 0.7814 - val_loss: 7.9872 - val_accuracy: 0.5473 - lr: 0.0010 - 6s/epoch - 825ms/step
# Epoch 41/800
#
# Epoch 00041: val_loss did not improve from 0.41839
# 7/7 - 6s - loss: 0.5772 - accuracy: 0.7723 - val_loss: 5.5224 - val_accuracy: 0.5473 - lr: 0.0010 - 6s/epoch - 838ms/step
# Epoch 42/800
#
# Epoch 00042: val_loss did not improve from 0.41839
# 7/7 - 6s - loss: 0.5224 - accuracy: 0.7744 - val_loss: 0.4462 - val_accuracy: 0.8330 - lr: 0.0010 - 6s/epoch - 808ms/step
# Epoch 43/800
#
# Epoch 00043: val_loss did not improve from 0.41839
# 7/7 - 6s - loss: 0.5164 - accuracy: 0.7930 - val_loss: 0.8502 - val_accuracy: 0.7404 - lr: 0.0010 - 6s/epoch - 852ms/step
# Epoch 44/800
#
# Epoch 00044: val_loss did not improve from 0.41839
# 7/7 - 6s - loss: 0.4865 - accuracy: 0.7997 - val_loss: 1.5581 - val_accuracy: 0.5654 - lr: 0.0010 - 6s/epoch - 848ms/step
# Epoch 45/800
#
# Epoch 00045: val_loss did not improve from 0.41839
# 7/7 - 6s - loss: 0.4729 - accuracy: 0.8045 - val_loss: 0.5711 - val_accuracy: 0.8270 - lr: 0.0010 - 6s/epoch - 822ms/step
# Epoch 46/800
#
# Epoch 00046: val_loss did not improve from 0.41839
# 7/7 - 6s - loss: 0.4720 - accuracy: 0.8138 - val_loss: 0.6114 - val_accuracy: 0.8089 - lr: 0.0010 - 6s/epoch - 817ms/step
# Epoch 47/800
#
# Epoch 00047: val_loss did not improve from 0.41839
# 7/7 - 6s - loss: 0.4855 - accuracy: 0.7953 - val_loss: 2.5682 - val_accuracy: 0.5433 - lr: 0.0010 - 6s/epoch - 831ms/step
# Epoch 48/800
#
# Epoch 00048: val_loss improved from 0.41839 to 0.34359, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 8s - loss: 0.5062 - accuracy: 0.7895 - val_loss: 0.3436 - val_accuracy: 0.8873 - lr: 0.0010 - 8s/epoch - 1s/step
# Epoch 49/800
#
# Epoch 00049: val_loss did not improve from 0.34359
# 7/7 - 6s - loss: 0.4630 - accuracy: 0.8051 - val_loss: 0.8595 - val_accuracy: 0.7364 - lr: 0.0010 - 6s/epoch - 832ms/step
# Epoch 50/800
#
# Epoch 00050: val_loss did not improve from 0.34359
# 7/7 - 6s - loss: 0.4434 - accuracy: 0.8201 - val_loss: 0.6608 - val_accuracy: 0.8149 - lr: 0.0010 - 6s/epoch - 865ms/step
# Epoch 51/800
#
# Epoch 00051: val_loss did not improve from 0.34359
# 7/7 - 6s - loss: 0.4580 - accuracy: 0.8143 - val_loss: 3.3638 - val_accuracy: 0.5473 - lr: 0.0010 - 6s/epoch - 846ms/step
# Epoch 52/800
#
# Epoch 00052: val_loss did not improve from 0.34359
# 7/7 - 6s - loss: 0.4240 - accuracy: 0.8207 - val_loss: 0.7629 - val_accuracy: 0.7062 - lr: 0.0010 - 6s/epoch - 787ms/step
# Epoch 53/800
#
# Epoch 00053: val_loss did not improve from 0.34359
# 7/7 - 6s - loss: 0.4481 - accuracy: 0.8281 - val_loss: 3.1142 - val_accuracy: 0.5473 - lr: 0.0010 - 6s/epoch - 850ms/step
# Epoch 54/800
#
# Epoch 00054: val_loss did not improve from 0.34359
# 7/7 - 6s - loss: 0.4619 - accuracy: 0.8167 - val_loss: 2.2287 - val_accuracy: 0.5473 - lr: 0.0010 - 6s/epoch - 816ms/step
# Epoch 55/800
#
# Epoch 00055: val_loss did not improve from 0.34359
# 7/7 - 6s - loss: 0.4591 - accuracy: 0.8207 - val_loss: 1.4395 - val_accuracy: 0.5614 - lr: 0.0010 - 6s/epoch - 818ms/step
# Epoch 56/800
#
# Epoch 00056: val_loss did not improve from 0.34359
# 7/7 - 6s - loss: 0.4520 - accuracy: 0.8265 - val_loss: 1.3223 - val_accuracy: 0.5734 - lr: 0.0010 - 6s/epoch - 828ms/step
# Epoch 57/800
#
# Epoch 00057: val_loss did not improve from 0.34359
# 7/7 - 6s - loss: 0.4607 - accuracy: 0.8115 - val_loss: 2.5166 - val_accuracy: 0.5473 - lr: 0.0010 - 6s/epoch - 828ms/step
# Epoch 58/800
#
# Epoch 00058: val_loss did not improve from 0.34359
# 7/7 - 6s - loss: 0.4292 - accuracy: 0.8294 - val_loss: 0.4335 - val_accuracy: 0.8511 - lr: 0.0010 - 6s/epoch - 816ms/step
# Epoch 59/800
#
# Epoch 00059: val_loss improved from 0.34359 to 0.31268, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 8s - loss: 0.4518 - accuracy: 0.8126 - val_loss: 0.3127 - val_accuracy: 0.8934 - lr: 0.0010 - 8s/epoch - 1s/step
# Epoch 60/800
#
# Epoch 00060: val_loss did not improve from 0.31268
# 7/7 - 6s - loss: 0.4262 - accuracy: 0.8479 - val_loss: 0.9009 - val_accuracy: 0.6881 - lr: 0.0010 - 6s/epoch - 833ms/step
# Epoch 61/800
#
# Epoch 00061: val_loss did not improve from 0.31268
# 7/7 - 6s - loss: 0.4145 - accuracy: 0.8382 - val_loss: 0.8733 - val_accuracy: 0.7545 - lr: 0.0010 - 6s/epoch - 865ms/step
# Epoch 62/800
#
# Epoch 00062: val_loss improved from 0.31268 to 0.29795, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 8s - loss: 0.4026 - accuracy: 0.8346 - val_loss: 0.2979 - val_accuracy: 0.9054 - lr: 0.0010 - 8s/epoch - 1s/step
# Epoch 63/800
#
# Epoch 00063: val_loss did not improve from 0.29795
# 7/7 - 6s - loss: 0.4080 - accuracy: 0.8309 - val_loss: 0.7623 - val_accuracy: 0.7767 - lr: 0.0010 - 6s/epoch - 844ms/step
# Epoch 64/800
#
# Epoch 00064: val_loss did not improve from 0.29795
# 7/7 - 6s - loss: 0.3596 - accuracy: 0.8571 - val_loss: 1.2734 - val_accuracy: 0.6861 - lr: 0.0010 - 6s/epoch - 883ms/step
# Epoch 65/800
#
# Epoch 00065: val_loss did not improve from 0.29795
# 7/7 - 6s - loss: 0.3894 - accuracy: 0.8490 - val_loss: 0.5795 - val_accuracy: 0.7787 - lr: 0.0010 - 6s/epoch - 818ms/step
# Epoch 66/800
#
# Epoch 00066: val_loss did not improve from 0.29795
# 7/7 - 6s - loss: 0.3708 - accuracy: 0.8519 - val_loss: 0.3013 - val_accuracy: 0.8994 - lr: 0.0010 - 6s/epoch - 835ms/step
# Epoch 67/800
#
# Epoch 00067: val_loss did not improve from 0.29795
# 7/7 - 6s - loss: 0.4001 - accuracy: 0.8525 - val_loss: 1.6262 - val_accuracy: 0.6137 - lr: 0.0010 - 6s/epoch - 822ms/step
# Epoch 68/800
#
# Epoch 00068: val_loss did not improve from 0.29795
# 7/7 - 6s - loss: 0.4103 - accuracy: 0.8369 - val_loss: 0.3027 - val_accuracy: 0.8913 - lr: 0.0010 - 6s/epoch - 823ms/step
# Epoch 69/800
#
# Epoch 00069: val_loss did not improve from 0.29795
# 7/7 - 6s - loss: 0.3979 - accuracy: 0.8543 - val_loss: 0.3329 - val_accuracy: 0.8913 - lr: 0.0010 - 6s/epoch - 805ms/step
# Epoch 70/800
#
# Epoch 00070: val_loss did not improve from 0.29795
# 7/7 - 6s - loss: 0.3838 - accuracy: 0.8467 - val_loss: 0.6314 - val_accuracy: 0.7867 - lr: 0.0010 - 6s/epoch - 817ms/step
# Epoch 71/800
#
# Epoch 00071: val_loss did not improve from 0.29795
# 7/7 - 6s - loss: 0.3661 - accuracy: 0.8543 - val_loss: 2.0106 - val_accuracy: 0.5473 - lr: 0.0010 - 6s/epoch - 821ms/step
# Epoch 72/800
#
# Epoch 00072: val_loss did not improve from 0.29795
# 7/7 - 6s - loss: 0.4121 - accuracy: 0.8485 - val_loss: 0.6180 - val_accuracy: 0.8008 - lr: 0.0010 - 6s/epoch - 821ms/step
# Epoch 73/800
#
# Epoch 00073: val_loss did not improve from 0.29795
# 7/7 - 6s - loss: 0.4202 - accuracy: 0.8323 - val_loss: 1.8969 - val_accuracy: 0.5473 - lr: 0.0010 - 6s/epoch - 818ms/step
# Epoch 74/800
#
# Epoch 00074: val_loss did not improve from 0.29795
# 7/7 - 6s - loss: 0.3974 - accuracy: 0.8304 - val_loss: 0.4710 - val_accuracy: 0.8229 - lr: 0.0010 - 6s/epoch - 839ms/step
# Epoch 75/800
#
# Epoch 00075: val_loss improved from 0.29795 to 0.26356, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 8s - loss: 0.3830 - accuracy: 0.8386 - val_loss: 0.2636 - val_accuracy: 0.8954 - lr: 0.0010 - 8s/epoch - 1s/step
# Epoch 76/800
#
# Epoch 00076: val_loss did not improve from 0.26356
# 7/7 - 6s - loss: 0.3757 - accuracy: 0.8490 - val_loss: 0.9482 - val_accuracy: 0.6056 - lr: 0.0010 - 6s/epoch - 839ms/step
# Epoch 77/800
#
# Epoch 00077: val_loss did not improve from 0.26356
# 7/7 - 6s - loss: 0.3574 - accuracy: 0.8677 - val_loss: 0.5892 - val_accuracy: 0.7988 - lr: 0.0010 - 6s/epoch - 883ms/step
# Epoch 78/800
#
# Epoch 00078: val_loss did not improve from 0.26356
# 7/7 - 6s - loss: 0.3641 - accuracy: 0.8527 - val_loss: 0.4727 - val_accuracy: 0.8330 - lr: 0.0010 - 6s/epoch - 866ms/step
# Epoch 79/800
#
# Epoch 00079: val_loss did not improve from 0.26356
# 7/7 - 6s - loss: 0.3492 - accuracy: 0.8687 - val_loss: 0.2815 - val_accuracy: 0.9014 - lr: 0.0010 - 6s/epoch - 828ms/step
# Epoch 80/800
#
# Epoch 00080: val_loss did not improve from 0.26356
# 7/7 - 6s - loss: 0.3554 - accuracy: 0.8623 - val_loss: 0.3440 - val_accuracy: 0.8753 - lr: 0.0010 - 6s/epoch - 800ms/step
# Epoch 81/800
#
# Epoch 00081: val_loss did not improve from 0.26356
# 7/7 - 6s - loss: 0.3558 - accuracy: 0.8647 - val_loss: 1.1717 - val_accuracy: 0.6559 - lr: 0.0010 - 6s/epoch - 824ms/step
# Epoch 82/800
#
# Epoch 00082: val_loss did not improve from 0.26356
# 7/7 - 6s - loss: 0.3671 - accuracy: 0.8566 - val_loss: 0.3034 - val_accuracy: 0.8893 - lr: 0.0010 - 6s/epoch - 805ms/step
# Epoch 83/800
#
# Epoch 00083: val_loss did not improve from 0.26356
# 7/7 - 6s - loss: 0.3518 - accuracy: 0.8635 - val_loss: 0.3426 - val_accuracy: 0.8632 - lr: 0.0010 - 6s/epoch - 831ms/step
# Epoch 84/800
#
# Epoch 00084: val_loss did not improve from 0.26356
# 7/7 - 6s - loss: 0.3439 - accuracy: 0.8600 - val_loss: 0.4606 - val_accuracy: 0.8390 - lr: 0.0010 - 6s/epoch - 826ms/step
# Epoch 85/800
#
# Epoch 00085: val_loss did not improve from 0.26356
# 7/7 - 6s - loss: 0.3426 - accuracy: 0.8710 - val_loss: 0.5543 - val_accuracy: 0.8089 - lr: 0.0010 - 6s/epoch - 814ms/step
# Epoch 86/800
#
# Epoch 00086: val_loss did not improve from 0.26356
# 7/7 - 6s - loss: 0.3476 - accuracy: 0.8599 - val_loss: 0.7778 - val_accuracy: 0.7344 - lr: 0.0010 - 6s/epoch - 850ms/step
# Epoch 87/800
#
# Epoch 00087: val_loss did not improve from 0.26356
# 7/7 - 6s - loss: 0.3826 - accuracy: 0.8566 - val_loss: 0.3114 - val_accuracy: 0.8833 - lr: 0.0010 - 6s/epoch - 822ms/step
# Epoch 88/800
#
# Epoch 00088: val_loss did not improve from 0.26356
# 7/7 - 6s - loss: 0.3369 - accuracy: 0.8622 - val_loss: 0.2691 - val_accuracy: 0.8974 - lr: 0.0010 - 6s/epoch - 839ms/step
# Epoch 89/800
#
# Epoch 00089: val_loss did not improve from 0.26356
# 7/7 - 6s - loss: 0.3283 - accuracy: 0.8676 - val_loss: 0.6642 - val_accuracy: 0.6821 - lr: 0.0010 - 6s/epoch - 826ms/step
# Epoch 90/800
#
# Epoch 00090: val_loss did not improve from 0.26356
# 7/7 - 6s - loss: 0.3246 - accuracy: 0.8699 - val_loss: 0.7318 - val_accuracy: 0.7223 - lr: 0.0010 - 6s/epoch - 825ms/step
# Epoch 91/800
#
# Epoch 00091: val_loss did not improve from 0.26356
# 7/7 - 6s - loss: 0.3752 - accuracy: 0.8554 - val_loss: 0.3159 - val_accuracy: 0.8954 - lr: 0.0010 - 6s/epoch - 819ms/step
# Epoch 92/800
#
# Epoch 00092: val_loss did not improve from 0.26356
# 7/7 - 6s - loss: 0.3250 - accuracy: 0.8717 - val_loss: 0.4707 - val_accuracy: 0.8129 - lr: 0.0010 - 6s/epoch - 855ms/step
# Epoch 93/800
#
# Epoch 00093: val_loss improved from 0.26356 to 0.25379, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 8s - loss: 0.3167 - accuracy: 0.8861 - val_loss: 0.2538 - val_accuracy: 0.9054 - lr: 0.0010 - 8s/epoch - 1s/step
# Epoch 94/800
#
# Epoch 00094: val_loss did not improve from 0.25379
# 7/7 - 6s - loss: 0.3358 - accuracy: 0.8687 - val_loss: 0.2746 - val_accuracy: 0.8994 - lr: 0.0010 - 6s/epoch - 827ms/step
# Epoch 95/800
#
# Epoch 00095: val_loss did not improve from 0.25379
# 7/7 - 6s - loss: 0.3432 - accuracy: 0.8694 - val_loss: 0.3079 - val_accuracy: 0.8853 - lr: 0.0010 - 6s/epoch - 860ms/step
# Epoch 96/800
#
# Epoch 00096: val_loss did not improve from 0.25379
# 7/7 - 6s - loss: 0.3561 - accuracy: 0.8641 - val_loss: 0.8574 - val_accuracy: 0.6660 - lr: 0.0010 - 6s/epoch - 828ms/step
# Epoch 97/800
#
# Epoch 00097: val_loss did not improve from 0.25379
# 7/7 - 6s - loss: 0.3401 - accuracy: 0.8664 - val_loss: 0.5991 - val_accuracy: 0.7988 - lr: 0.0010 - 6s/epoch - 817ms/step
# Epoch 98/800
#
# Epoch 00098: val_loss did not improve from 0.25379
# 7/7 - 6s - loss: 0.3419 - accuracy: 0.8728 - val_loss: 0.5332 - val_accuracy: 0.8189 - lr: 0.0010 - 6s/epoch - 790ms/step
# Epoch 99/800
#
# Epoch 00099: val_loss did not improve from 0.25379
# 7/7 - 6s - loss: 0.3295 - accuracy: 0.8722 - val_loss: 0.2586 - val_accuracy: 0.9095 - lr: 0.0010 - 6s/epoch - 815ms/step
# Epoch 100/800
#
# Epoch 00100: val_loss did not improve from 0.25379
# 7/7 - 6s - loss: 0.3338 - accuracy: 0.8699 - val_loss: 0.3506 - val_accuracy: 0.8793 - lr: 0.0010 - 6s/epoch - 830ms/step
# Epoch 101/800
#
# Epoch 00101: val_loss did not improve from 0.25379
# 7/7 - 6s - loss: 0.3142 - accuracy: 0.8728 - val_loss: 0.5051 - val_accuracy: 0.8330 - lr: 0.0010 - 6s/epoch - 821ms/step
# Epoch 102/800
#
# Epoch 00102: val_loss did not improve from 0.25379
# 7/7 - 6s - loss: 0.3256 - accuracy: 0.8676 - val_loss: 0.8740 - val_accuracy: 0.7203 - lr: 0.0010 - 6s/epoch - 824ms/step
# Epoch 103/800
#
# Epoch 00103: val_loss did not improve from 0.25379
# 7/7 - 6s - loss: 0.3190 - accuracy: 0.8751 - val_loss: 0.5777 - val_accuracy: 0.7847 - lr: 0.0010 - 6s/epoch - 823ms/step
# Epoch 104/800
#
# Epoch 00104: val_loss did not improve from 0.25379
# 7/7 - 6s - loss: 0.3144 - accuracy: 0.8774 - val_loss: 0.2875 - val_accuracy: 0.8913 - lr: 0.0010 - 6s/epoch - 830ms/step
# Epoch 105/800
#
# Epoch 00105: val_loss improved from 0.25379 to 0.23647, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 8s - loss: 0.2960 - accuracy: 0.8826 - val_loss: 0.2365 - val_accuracy: 0.9054 - lr: 0.0010 - 8s/epoch - 1s/step
# Epoch 106/800
#
# Epoch 00106: val_loss did not improve from 0.23647
# 7/7 - 6s - loss: 0.3340 - accuracy: 0.8658 - val_loss: 0.3039 - val_accuracy: 0.8853 - lr: 0.0010 - 6s/epoch - 829ms/step
# Epoch 107/800
#
# Epoch 00107: val_loss did not improve from 0.23647
# 7/7 - 6s - loss: 0.3159 - accuracy: 0.8803 - val_loss: 0.2531 - val_accuracy: 0.9034 - lr: 0.0010 - 6s/epoch - 837ms/step
# Epoch 108/800
#
# Epoch 00108: val_loss did not improve from 0.23647
# 7/7 - 6s - loss: 0.3000 - accuracy: 0.8866 - val_loss: 0.6496 - val_accuracy: 0.7928 - lr: 0.0010 - 6s/epoch - 863ms/step
# Epoch 109/800
#
# Epoch 00109: val_loss did not improve from 0.23647
# 7/7 - 6s - loss: 0.3139 - accuracy: 0.8837 - val_loss: 0.2510 - val_accuracy: 0.9054 - lr: 0.0010 - 6s/epoch - 818ms/step
# Epoch 110/800
#
# Epoch 00110: val_loss did not improve from 0.23647
# 7/7 - 6s - loss: 0.3023 - accuracy: 0.8797 - val_loss: 0.7991 - val_accuracy: 0.6942 - lr: 0.0010 - 6s/epoch - 820ms/step
# Epoch 111/800
#
# Epoch 00111: val_loss did not improve from 0.23647
# 7/7 - 6s - loss: 0.3037 - accuracy: 0.8780 - val_loss: 0.2453 - val_accuracy: 0.9074 - lr: 0.0010 - 6s/epoch - 824ms/step
# Epoch 112/800
#
# Epoch 00112: val_loss did not improve from 0.23647
# 7/7 - 6s - loss: 0.2977 - accuracy: 0.8814 - val_loss: 0.3360 - val_accuracy: 0.8813 - lr: 0.0010 - 6s/epoch - 826ms/step
# Epoch 113/800
#
# Epoch 00113: val_loss did not improve from 0.23647
# 7/7 - 6s - loss: 0.3058 - accuracy: 0.8791 - val_loss: 0.2543 - val_accuracy: 0.9074 - lr: 0.0010 - 6s/epoch - 817ms/step
# Epoch 114/800
#
# Epoch 00114: val_loss improved from 0.23647 to 0.23112, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 8s - loss: 0.3232 - accuracy: 0.8780 - val_loss: 0.2311 - val_accuracy: 0.9135 - lr: 0.0010 - 8s/epoch - 1s/step
# Epoch 115/800
#
# Epoch 00115: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2767 - accuracy: 0.8959 - val_loss: 2.0992 - val_accuracy: 0.5734 - lr: 0.0010 - 6s/epoch - 810ms/step
# Epoch 116/800
#
# Epoch 00116: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.3006 - accuracy: 0.8800 - val_loss: 0.2547 - val_accuracy: 0.9115 - lr: 0.0010 - 6s/epoch - 889ms/step
# Epoch 117/800
#
# Epoch 00117: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.3275 - accuracy: 0.8728 - val_loss: 1.0003 - val_accuracy: 0.7344 - lr: 0.0010 - 6s/epoch - 878ms/step
# Epoch 118/800
#
# Epoch 00118: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2785 - accuracy: 0.8976 - val_loss: 1.6846 - val_accuracy: 0.6117 - lr: 0.0010 - 6s/epoch - 814ms/step
# Epoch 119/800
#
# Epoch 00119: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.3280 - accuracy: 0.8704 - val_loss: 0.3188 - val_accuracy: 0.8652 - lr: 0.0010 - 6s/epoch - 816ms/step
# Epoch 120/800
#
# Epoch 00120: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.3061 - accuracy: 0.8803 - val_loss: 1.0156 - val_accuracy: 0.5895 - lr: 0.0010 - 6s/epoch - 817ms/step
# Epoch 121/800
#
# Epoch 00121: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2745 - accuracy: 0.8982 - val_loss: 0.2790 - val_accuracy: 0.8873 - lr: 0.0010 - 6s/epoch - 831ms/step
# Epoch 122/800
#
# Epoch 00122: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2739 - accuracy: 0.8942 - val_loss: 0.3520 - val_accuracy: 0.8511 - lr: 0.0010 - 6s/epoch - 826ms/step
# Epoch 123/800
#
# Epoch 00123: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2927 - accuracy: 0.8862 - val_loss: 0.2497 - val_accuracy: 0.9074 - lr: 0.0010 - 6s/epoch - 851ms/step
# Epoch 124/800
#
# Epoch 00124: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2838 - accuracy: 0.8849 - val_loss: 0.2761 - val_accuracy: 0.8913 - lr: 0.0010 - 6s/epoch - 823ms/step
# Epoch 125/800
#
# Epoch 00125: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2936 - accuracy: 0.8924 - val_loss: 0.2472 - val_accuracy: 0.9074 - lr: 0.0010 - 6s/epoch - 830ms/step
# Epoch 126/800
#
# Epoch 00126: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2643 - accuracy: 0.8976 - val_loss: 0.7021 - val_accuracy: 0.7847 - lr: 0.0010 - 6s/epoch - 807ms/step
# Epoch 127/800
#
# Epoch 00127: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2799 - accuracy: 0.8982 - val_loss: 0.4769 - val_accuracy: 0.8410 - lr: 0.0010 - 6s/epoch - 824ms/step
# Epoch 128/800
#
# Epoch 00128: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2787 - accuracy: 0.8947 - val_loss: 0.3168 - val_accuracy: 0.8934 - lr: 0.0010 - 6s/epoch - 825ms/step
# Epoch 129/800
#
# Epoch 00129: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.3166 - accuracy: 0.8820 - val_loss: 0.2490 - val_accuracy: 0.9155 - lr: 0.0010 - 6s/epoch - 826ms/step
# Epoch 130/800
#
# Epoch 00130: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.3223 - accuracy: 0.8783 - val_loss: 0.2889 - val_accuracy: 0.8994 - lr: 0.0010 - 6s/epoch - 847ms/step
# Epoch 131/800
#
# Epoch 00131: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2771 - accuracy: 0.8873 - val_loss: 0.5090 - val_accuracy: 0.8229 - lr: 0.0010 - 6s/epoch - 852ms/step
# Epoch 132/800
#
# Epoch 00132: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2762 - accuracy: 0.8872 - val_loss: 0.3036 - val_accuracy: 0.8873 - lr: 0.0010 - 6s/epoch - 825ms/step
# Epoch 133/800
#
# Epoch 00133: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.3226 - accuracy: 0.8803 - val_loss: 0.4512 - val_accuracy: 0.8672 - lr: 0.0010 - 6s/epoch - 825ms/step
# Epoch 134/800
#
# Epoch 00134: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2740 - accuracy: 0.8901 - val_loss: 0.2371 - val_accuracy: 0.9155 - lr: 0.0010 - 6s/epoch - 835ms/step
# Epoch 135/800
#
# Epoch 00135: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2813 - accuracy: 0.8861 - val_loss: 0.6837 - val_accuracy: 0.6922 - lr: 0.0010 - 6s/epoch - 809ms/step
# Epoch 136/800
#
# Epoch 00136: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2652 - accuracy: 0.8959 - val_loss: 0.3377 - val_accuracy: 0.8592 - lr: 0.0010 - 6s/epoch - 820ms/step
# Epoch 137/800
#
# Epoch 00137: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2744 - accuracy: 0.8878 - val_loss: 0.3433 - val_accuracy: 0.8813 - lr: 0.0010 - 6s/epoch - 820ms/step
# Epoch 138/800
#
# Epoch 00138: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2740 - accuracy: 0.8988 - val_loss: 0.4797 - val_accuracy: 0.7827 - lr: 0.0010 - 6s/epoch - 819ms/step
# Epoch 139/800
#
# Epoch 00139: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2880 - accuracy: 0.8861 - val_loss: 0.2617 - val_accuracy: 0.8853 - lr: 0.0010 - 6s/epoch - 819ms/step
# Epoch 140/800
#
# Epoch 00140: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2817 - accuracy: 0.8791 - val_loss: 0.2545 - val_accuracy: 0.8994 - lr: 0.0010 - 6s/epoch - 830ms/step
# Epoch 141/800
#
# Epoch 00141: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2620 - accuracy: 0.8907 - val_loss: 0.5394 - val_accuracy: 0.8290 - lr: 0.0010 - 6s/epoch - 820ms/step
# Epoch 142/800
#
# Epoch 00142: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2679 - accuracy: 0.8942 - val_loss: 0.3868 - val_accuracy: 0.8229 - lr: 0.0010 - 6s/epoch - 823ms/step
# Epoch 143/800
#
# Epoch 00143: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2762 - accuracy: 0.8953 - val_loss: 0.2456 - val_accuracy: 0.8873 - lr: 0.0010 - 6s/epoch - 814ms/step
# Epoch 144/800
#
# Epoch 00144: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2885 - accuracy: 0.8884 - val_loss: 0.4528 - val_accuracy: 0.7847 - lr: 0.0010 - 6s/epoch - 841ms/step
# Epoch 145/800
#
# Epoch 00145: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2781 - accuracy: 0.8861 - val_loss: 0.2635 - val_accuracy: 0.9074 - lr: 0.0010 - 6s/epoch - 846ms/step
# Epoch 146/800
#
# Epoch 00146: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2889 - accuracy: 0.8953 - val_loss: 0.6218 - val_accuracy: 0.7284 - lr: 0.0010 - 6s/epoch - 819ms/step
# Epoch 147/800
#
# Epoch 00147: val_loss did not improve from 0.23112
# 7/7 - 6s - loss: 0.2612 - accuracy: 0.9011 - val_loss: 0.3294 - val_accuracy: 0.8753 - lr: 0.0010 - 6s/epoch - 810ms/step
# Epoch 148/800
#
# Epoch 00148: val_loss improved from 0.23112 to 0.21796, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 8s - loss: 0.2528 - accuracy: 0.9005 - val_loss: 0.2180 - val_accuracy: 0.9235 - lr: 0.0010 - 8s/epoch - 1s/step
# Epoch 149/800
#
# Epoch 00149: val_loss did not improve from 0.21796
# 7/7 - 6s - loss: 0.2487 - accuracy: 0.9034 - val_loss: 0.4340 - val_accuracy: 0.7907 - lr: 0.0010 - 6s/epoch - 836ms/step
# Epoch 150/800
#
# Epoch 00150: val_loss did not improve from 0.21796
# 7/7 - 6s - loss: 0.2853 - accuracy: 0.8918 - val_loss: 0.9116 - val_accuracy: 0.7223 - lr: 0.0010 - 6s/epoch - 850ms/step
# Epoch 151/800
#
# Epoch 00151: val_loss improved from 0.21796 to 0.21692, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 8s - loss: 0.2450 - accuracy: 0.9063 - val_loss: 0.2169 - val_accuracy: 0.9135 - lr: 0.0010 - 8s/epoch - 1s/step
# Epoch 152/800
#
# Epoch 00152: val_loss did not improve from 0.21692
# 7/7 - 6s - loss: 0.2453 - accuracy: 0.9023 - val_loss: 0.4843 - val_accuracy: 0.8390 - lr: 0.0010 - 6s/epoch - 802ms/step
# Epoch 153/800
#
# Epoch 00153: val_loss did not improve from 0.21692
# 7/7 - 6s - loss: 0.2467 - accuracy: 0.9017 - val_loss: 0.5221 - val_accuracy: 0.8109 - lr: 0.0010 - 6s/epoch - 849ms/step
# Epoch 154/800
#
# Epoch 00154: val_loss did not improve from 0.21692
# 7/7 - 6s - loss: 0.2614 - accuracy: 0.9011 - val_loss: 0.9093 - val_accuracy: 0.7203 - lr: 0.0010 - 6s/epoch - 848ms/step
# Epoch 155/800
#
# Epoch 00155: val_loss did not improve from 0.21692
# 7/7 - 6s - loss: 0.2512 - accuracy: 0.8976 - val_loss: 0.4679 - val_accuracy: 0.7907 - lr: 0.0010 - 6s/epoch - 824ms/step
# Epoch 156/800
#
# Epoch 00156: val_loss did not improve from 0.21692
# 7/7 - 6s - loss: 0.2654 - accuracy: 0.9080 - val_loss: 0.3871 - val_accuracy: 0.8048 - lr: 0.0010 - 6s/epoch - 834ms/step
# Epoch 157/800
#
# Epoch 00157: val_loss did not improve from 0.21692
# 7/7 - 6s - loss: 0.2499 - accuracy: 0.9069 - val_loss: 0.2603 - val_accuracy: 0.8873 - lr: 0.0010 - 6s/epoch - 829ms/step
# Epoch 158/800
#
# Epoch 00158: val_loss did not improve from 0.21692
# 7/7 - 6s - loss: 0.2589 - accuracy: 0.8930 - val_loss: 0.4323 - val_accuracy: 0.8330 - lr: 0.0010 - 6s/epoch - 811ms/step
# Epoch 159/800
#
# Epoch 00159: val_loss did not improve from 0.21692
# 7/7 - 6s - loss: 0.2698 - accuracy: 0.8930 - val_loss: 0.4624 - val_accuracy: 0.8431 - lr: 0.0010 - 6s/epoch - 818ms/step
# Epoch 160/800
#
# Epoch 00160: val_loss did not improve from 0.21692
# 7/7 - 6s - loss: 0.2605 - accuracy: 0.8994 - val_loss: 0.2198 - val_accuracy: 0.9175 - lr: 0.0010 - 6s/epoch - 811ms/step
# Epoch 161/800
#
# Epoch 00161: val_loss did not improve from 0.21692
# 7/7 - 6s - loss: 0.2648 - accuracy: 0.9063 - val_loss: 0.2208 - val_accuracy: 0.9235 - lr: 0.0010 - 6s/epoch - 806ms/step
# Epoch 162/800
#
# Epoch 00162: val_loss did not improve from 0.21692
# 7/7 - 6s - loss: 0.2611 - accuracy: 0.9011 - val_loss: 0.6315 - val_accuracy: 0.8008 - lr: 0.0010 - 6s/epoch - 819ms/step
# Epoch 163/800
#
# Epoch 00163: val_loss did not improve from 0.21692
# 7/7 - 6s - loss: 0.2434 - accuracy: 0.8988 - val_loss: 0.2412 - val_accuracy: 0.9115 - lr: 0.0010 - 6s/epoch - 819ms/step
# Epoch 164/800
#
# Epoch 00164: val_loss did not improve from 0.21692
# 7/7 - 6s - loss: 0.2449 - accuracy: 0.9092 - val_loss: 0.2412 - val_accuracy: 0.9115 - lr: 0.0010 - 6s/epoch - 843ms/step
# Epoch 165/800
#
# Epoch 00165: val_loss did not improve from 0.21692
# 7/7 - 6s - loss: 0.2464 - accuracy: 0.9034 - val_loss: 0.2216 - val_accuracy: 0.9296 - lr: 0.0010 - 6s/epoch - 808ms/step
# Epoch 166/800
#
# Epoch 00166: val_loss did not improve from 0.21692
# 7/7 - 6s - loss: 0.2506 - accuracy: 0.9034 - val_loss: 0.5708 - val_accuracy: 0.7384 - lr: 0.0010 - 6s/epoch - 832ms/step
# Epoch 167/800
#
# Epoch 00167: val_loss did not improve from 0.21692
# 7/7 - 6s - loss: 0.2487 - accuracy: 0.9080 - val_loss: 0.4679 - val_accuracy: 0.7726 - lr: 0.0010 - 6s/epoch - 826ms/step
# Epoch 168/800
#
# Epoch 00168: val_loss did not improve from 0.21692
# 7/7 - 6s - loss: 0.2503 - accuracy: 0.9115 - val_loss: 0.2193 - val_accuracy: 0.9135 - lr: 0.0010 - 6s/epoch - 829ms/step
# Epoch 169/800
#
# Epoch 00169: val_loss improved from 0.21692 to 0.20035, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 8s - loss: 0.2305 - accuracy: 0.9104 - val_loss: 0.2004 - val_accuracy: 0.9296 - lr: 0.0010 - 8s/epoch - 1s/step
# Epoch 170/800
#
# Epoch 00170: val_loss did not improve from 0.20035
# 7/7 - 6s - loss: 0.2151 - accuracy: 0.9237 - val_loss: 0.2197 - val_accuracy: 0.9095 - lr: 0.0010 - 6s/epoch - 833ms/step
# Epoch 171/800
#
# Epoch 00171: val_loss did not improve from 0.20035
# 7/7 - 6s - loss: 0.2191 - accuracy: 0.9161 - val_loss: 0.2399 - val_accuracy: 0.8934 - lr: 0.0010 - 6s/epoch - 846ms/step
# Epoch 172/800
#
# Epoch 00172: val_loss did not improve from 0.20035
# 7/7 - 6s - loss: 0.2408 - accuracy: 0.8994 - val_loss: 0.3546 - val_accuracy: 0.8249 - lr: 0.0010 - 6s/epoch - 839ms/step
# Epoch 173/800
#
# Epoch 00173: val_loss did not improve from 0.20035
# 7/7 - 6s - loss: 0.2218 - accuracy: 0.9118 - val_loss: 0.2100 - val_accuracy: 0.9276 - lr: 0.0010 - 6s/epoch - 846ms/step
# Epoch 174/800
#
# Epoch 00174: val_loss did not improve from 0.20035
# 7/7 - 6s - loss: 0.2387 - accuracy: 0.9075 - val_loss: 0.4951 - val_accuracy: 0.7807 - lr: 0.0010 - 6s/epoch - 843ms/step
# Epoch 175/800
#
# Epoch 00175: val_loss improved from 0.20035 to 0.20012, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 8s - loss: 0.2335 - accuracy: 0.9173 - val_loss: 0.2001 - val_accuracy: 0.9276 - lr: 0.0010 - 8s/epoch - 1s/step
# Epoch 176/800
#
# Epoch 00176: val_loss did not improve from 0.20012
# 7/7 - 6s - loss: 0.2378 - accuracy: 0.9069 - val_loss: 0.3526 - val_accuracy: 0.8813 - lr: 0.0010 - 6s/epoch - 834ms/step
# Epoch 177/800
#
# Epoch 00177: val_loss did not improve from 0.20012
# 7/7 - 6s - loss: 0.2348 - accuracy: 0.9104 - val_loss: 0.2326 - val_accuracy: 0.9155 - lr: 0.0010 - 6s/epoch - 851ms/step
# Epoch 178/800
#
# Epoch 00178: val_loss did not improve from 0.20012
# 7/7 - 6s - loss: 0.2197 - accuracy: 0.9163 - val_loss: 1.0621 - val_accuracy: 0.5956 - lr: 0.0010 - 6s/epoch - 869ms/step
# Epoch 179/800
#
# Epoch 00179: val_loss did not improve from 0.20012
# 7/7 - 6s - loss: 0.2337 - accuracy: 0.9079 - val_loss: 0.7887 - val_accuracy: 0.6801 - lr: 0.0010 - 6s/epoch - 848ms/step
# Epoch 180/800
#
# Epoch 00180: val_loss did not improve from 0.20012
# 7/7 - 6s - loss: 0.2540 - accuracy: 0.8965 - val_loss: 0.3464 - val_accuracy: 0.8531 - lr: 0.0010 - 6s/epoch - 813ms/step
# Epoch 181/800
#
# Epoch 00181: val_loss did not improve from 0.20012
# 7/7 - 6s - loss: 0.2344 - accuracy: 0.9127 - val_loss: 0.2918 - val_accuracy: 0.8974 - lr: 0.0010 - 6s/epoch - 829ms/step
# Epoch 182/800
#
# Epoch 00182: val_loss did not improve from 0.20012
# 7/7 - 6s - loss: 0.2417 - accuracy: 0.8936 - val_loss: 0.2751 - val_accuracy: 0.9155 - lr: 0.0010 - 6s/epoch - 820ms/step
# Epoch 183/800
#
# Epoch 00183: val_loss did not improve from 0.20012
# 7/7 - 6s - loss: 0.2307 - accuracy: 0.9132 - val_loss: 1.6402 - val_accuracy: 0.6740 - lr: 0.0010 - 6s/epoch - 817ms/step
# Epoch 184/800
#
# Epoch 00184: val_loss did not improve from 0.20012
# 7/7 - 6s - loss: 0.2086 - accuracy: 0.9152 - val_loss: 0.5024 - val_accuracy: 0.8310 - lr: 0.0010 - 6s/epoch - 862ms/step
# Epoch 185/800
#
# Epoch 00185: val_loss did not improve from 0.20012
# 7/7 - 6s - loss: 0.2178 - accuracy: 0.9196 - val_loss: 0.2806 - val_accuracy: 0.9014 - lr: 0.0010 - 6s/epoch - 824ms/step
# Epoch 186/800
#
# Epoch 00186: val_loss did not improve from 0.20012
# 7/7 - 6s - loss: 0.2370 - accuracy: 0.9109 - val_loss: 0.5845 - val_accuracy: 0.8310 - lr: 0.0010 - 6s/epoch - 816ms/step
# Epoch 187/800
#
# Epoch 00187: val_loss did not improve from 0.20012
# 7/7 - 6s - loss: 0.2516 - accuracy: 0.9040 - val_loss: 0.2676 - val_accuracy: 0.9115 - lr: 0.0010 - 6s/epoch - 807ms/step
# Epoch 188/800
#
# Epoch 00188: val_loss did not improve from 0.20012
# 7/7 - 6s - loss: 0.2510 - accuracy: 0.9011 - val_loss: 0.5280 - val_accuracy: 0.7706 - lr: 0.0010 - 6s/epoch - 826ms/step
# Epoch 189/800
#
# Epoch 00189: val_loss improved from 0.20012 to 0.19613, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 8s - loss: 0.2337 - accuracy: 0.9051 - val_loss: 0.1961 - val_accuracy: 0.9296 - lr: 0.0010 - 8s/epoch - 1s/step
# Epoch 190/800
#
# Epoch 00190: val_loss did not improve from 0.19613
# 7/7 - 6s - loss: 0.2188 - accuracy: 0.9132 - val_loss: 0.2112 - val_accuracy: 0.9155 - lr: 0.0010 - 6s/epoch - 843ms/step
# Epoch 191/800
#
# Epoch 00191: val_loss did not improve from 0.19613
# 7/7 - 6s - loss: 0.2195 - accuracy: 0.9115 - val_loss: 0.2462 - val_accuracy: 0.9135 - lr: 0.0010 - 6s/epoch - 849ms/step
# Epoch 192/800
#
# Epoch 00192: val_loss did not improve from 0.19613
# 7/7 - 6s - loss: 0.2171 - accuracy: 0.9129 - val_loss: 0.2189 - val_accuracy: 0.9316 - lr: 0.0010 - 6s/epoch - 874ms/step
# Epoch 193/800
#
# Epoch 00193: val_loss did not improve from 0.19613
# 7/7 - 6s - loss: 0.2241 - accuracy: 0.9184 - val_loss: 0.4564 - val_accuracy: 0.8592 - lr: 0.0010 - 6s/epoch - 826ms/step
# Epoch 194/800
#
# Epoch 00194: val_loss improved from 0.19613 to 0.18287, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 8s - loss: 0.2257 - accuracy: 0.9092 - val_loss: 0.1829 - val_accuracy: 0.9376 - lr: 0.0010 - 8s/epoch - 1s/step
# Epoch 195/800
#
# Epoch 00195: val_loss did not improve from 0.18287
# 7/7 - 6s - loss: 0.2237 - accuracy: 0.9127 - val_loss: 0.3521 - val_accuracy: 0.8652 - lr: 0.0010 - 6s/epoch - 826ms/step
# Epoch 196/800
#
# Epoch 00196: val_loss did not improve from 0.18287
# 7/7 - 6s - loss: 0.2269 - accuracy: 0.9109 - val_loss: 0.2295 - val_accuracy: 0.9215 - lr: 0.0010 - 6s/epoch - 881ms/step
# Epoch 197/800
#
# Epoch 00197: val_loss did not improve from 0.18287
# 7/7 - 6s - loss: 0.2209 - accuracy: 0.9132 - val_loss: 0.2310 - val_accuracy: 0.9054 - lr: 0.0010 - 6s/epoch - 867ms/step
# Epoch 198/800
#
# Epoch 00198: val_loss did not improve from 0.18287
# 7/7 - 6s - loss: 0.2218 - accuracy: 0.9196 - val_loss: 0.2590 - val_accuracy: 0.9155 - lr: 0.0010 - 6s/epoch - 836ms/step
# Epoch 199/800
#
# Epoch 00199: val_loss did not improve from 0.18287
# 7/7 - 6s - loss: 0.2144 - accuracy: 0.9213 - val_loss: 0.1999 - val_accuracy: 0.9356 - lr: 0.0010 - 6s/epoch - 831ms/step
# Epoch 200/800
#
# Epoch 00200: val_loss did not improve from 0.18287
# 7/7 - 6s - loss: 0.2064 - accuracy: 0.9156 - val_loss: 0.2034 - val_accuracy: 0.9316 - lr: 0.0010 - 6s/epoch - 832ms/step
# Epoch 201/800
#
# Epoch 00201: val_loss did not improve from 0.18287
# 7/7 - 6s - loss: 0.1964 - accuracy: 0.9231 - val_loss: 0.8200 - val_accuracy: 0.7565 - lr: 0.0010 - 6s/epoch - 816ms/step
# Epoch 202/800
#
# Epoch 00202: val_loss did not improve from 0.18287
# 7/7 - 6s - loss: 0.2222 - accuracy: 0.9161 - val_loss: 0.3191 - val_accuracy: 0.8712 - lr: 0.0010 - 6s/epoch - 814ms/step
# Epoch 203/800
#
# Epoch 00203: val_loss did not improve from 0.18287
# 7/7 - 6s - loss: 0.2323 - accuracy: 0.9132 - val_loss: 0.2563 - val_accuracy: 0.8853 - lr: 0.0010 - 6s/epoch - 830ms/step
# Epoch 204/800
#
# Epoch 00204: val_loss did not improve from 0.18287
# 7/7 - 6s - loss: 0.2072 - accuracy: 0.9231 - val_loss: 0.2249 - val_accuracy: 0.9014 - lr: 0.0010 - 6s/epoch - 826ms/step
# Epoch 205/800
#
# Epoch 00205: val_loss did not improve from 0.18287
# 7/7 - 6s - loss: 0.2169 - accuracy: 0.9144 - val_loss: 0.7283 - val_accuracy: 0.6700 - lr: 0.0010 - 6s/epoch - 831ms/step
# Epoch 206/800
#
# Epoch 00206: val_loss did not improve from 0.18287
# 7/7 - 6s - loss: 0.2119 - accuracy: 0.9098 - val_loss: 0.2301 - val_accuracy: 0.8893 - lr: 0.0010 - 6s/epoch - 816ms/step
# Epoch 207/800
#
# Epoch 00207: val_loss improved from 0.18287 to 0.17759, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 8s - loss: 0.1855 - accuracy: 0.9260 - val_loss: 0.1776 - val_accuracy: 0.9296 - lr: 0.0010 - 8s/epoch - 1s/step
# Epoch 208/800
#
# Epoch 00208: val_loss did not improve from 0.17759
# 7/7 - 6s - loss: 0.2017 - accuracy: 0.9225 - val_loss: 0.2097 - val_accuracy: 0.9215 - lr: 0.0010 - 6s/epoch - 847ms/step
# Epoch 209/800
#
# Epoch 00209: val_loss did not improve from 0.17759
# 7/7 - 6s - loss: 0.1889 - accuracy: 0.9297 - val_loss: 0.3363 - val_accuracy: 0.8511 - lr: 0.0010 - 6s/epoch - 899ms/step
# Epoch 210/800
#
# Epoch 00210: val_loss did not improve from 0.17759
# 7/7 - 6s - loss: 0.2011 - accuracy: 0.9225 - val_loss: 0.2026 - val_accuracy: 0.9376 - lr: 0.0010 - 6s/epoch - 844ms/step
# Epoch 211/800
#
# Epoch 00211: val_loss did not improve from 0.17759
# 7/7 - 6s - loss: 0.1939 - accuracy: 0.9161 - val_loss: 0.4691 - val_accuracy: 0.8028 - lr: 0.0010 - 6s/epoch - 832ms/step
# Epoch 212/800
#
# Epoch 00212: val_loss did not improve from 0.17759
# 7/7 - 6s - loss: 0.1913 - accuracy: 0.9300 - val_loss: 0.2045 - val_accuracy: 0.9336 - lr: 0.0010 - 6s/epoch - 825ms/step
# Epoch 213/800
#
# Epoch 00213: val_loss did not improve from 0.17759
# 7/7 - 6s - loss: 0.2063 - accuracy: 0.9144 - val_loss: 0.1844 - val_accuracy: 0.9396 - lr: 0.0010 - 6s/epoch - 822ms/step
# Epoch 214/800
#
# Epoch 00214: val_loss did not improve from 0.17759
# 7/7 - 6s - loss: 0.1986 - accuracy: 0.9265 - val_loss: 0.5352 - val_accuracy: 0.8290 - lr: 0.0010 - 6s/epoch - 812ms/step
# Epoch 215/800
#
# Epoch 00215: val_loss did not improve from 0.17759
# 7/7 - 6s - loss: 0.2124 - accuracy: 0.9225 - val_loss: 0.4750 - val_accuracy: 0.8028 - lr: 0.0010 - 6s/epoch - 837ms/step
# Epoch 216/800
#
# Epoch 00216: val_loss did not improve from 0.17759
# 7/7 - 6s - loss: 0.1889 - accuracy: 0.9271 - val_loss: 0.3741 - val_accuracy: 0.8652 - lr: 0.0010 - 6s/epoch - 837ms/step
# Epoch 217/800
#
# Epoch 00217: val_loss did not improve from 0.17759
# 7/7 - 6s - loss: 0.2080 - accuracy: 0.9156 - val_loss: 0.1971 - val_accuracy: 0.9296 - lr: 0.0010 - 6s/epoch - 829ms/step
# Epoch 218/800
#
# Epoch 00218: val_loss did not improve from 0.17759
# 7/7 - 6s - loss: 0.1889 - accuracy: 0.9283 - val_loss: 0.3091 - val_accuracy: 0.8712 - lr: 0.0010 - 6s/epoch - 820ms/step
# Epoch 219/800
#
# Epoch 00219: val_loss did not improve from 0.17759
# 7/7 - 6s - loss: 0.2126 - accuracy: 0.9225 - val_loss: 0.2882 - val_accuracy: 0.9074 - lr: 0.0010 - 6s/epoch - 804ms/step
# Epoch 220/800
#
# Epoch 00220: val_loss did not improve from 0.17759
# 7/7 - 6s - loss: 0.2033 - accuracy: 0.9190 - val_loss: 0.1909 - val_accuracy: 0.9235 - lr: 0.0010 - 6s/epoch - 829ms/step
# Epoch 221/800
#
# Epoch 00221: val_loss did not improve from 0.17759
# 7/7 - 6s - loss: 0.1881 - accuracy: 0.9370 - val_loss: 0.1930 - val_accuracy: 0.9336 - lr: 0.0010 - 6s/epoch - 828ms/step
# Epoch 222/800
#
# Epoch 00222: val_loss did not improve from 0.17759
# 7/7 - 6s - loss: 0.2077 - accuracy: 0.9219 - val_loss: 0.3070 - val_accuracy: 0.8833 - lr: 0.0010 - 6s/epoch - 813ms/step
# Epoch 223/800
#
# Epoch 00223: val_loss did not improve from 0.17759
# 7/7 - 6s - loss: 0.1748 - accuracy: 0.9283 - val_loss: 0.2083 - val_accuracy: 0.9316 - lr: 0.0010 - 6s/epoch - 827ms/step
# Epoch 224/800
#
# Epoch 00224: val_loss did not improve from 0.17759
# 7/7 - 6s - loss: 0.2055 - accuracy: 0.9283 - val_loss: 0.3116 - val_accuracy: 0.8994 - lr: 0.0010 - 6s/epoch - 848ms/step
# Epoch 225/800
#
# ...
# 7/7 - 6s - loss: 0.0333 - accuracy: 0.9873 - val_loss: 0.1791 - val_accuracy: 0.9477 - lr: 0.0010 - 6s/epoch - 819ms/step
# Epoch 717/800
#
# Epoch 00717: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0299 - accuracy: 0.9907 - val_loss: 0.2329 - val_accuracy: 0.9356 - lr: 0.0010 - 6s/epoch - 809ms/step
# Epoch 718/800
#
# Epoch 00718: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0385 - accuracy: 0.9855 - val_loss: 0.1104 - val_accuracy: 0.9698 - lr: 0.0010 - 6s/epoch - 833ms/step
# Epoch 719/800
#
# Epoch 00719: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0419 - accuracy: 0.9850 - val_loss: 0.5042 - val_accuracy: 0.9014 - lr: 0.0010 - 6s/epoch - 825ms/step
# Epoch 720/800
#
# Epoch 00720: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0417 - accuracy: 0.9879 - val_loss: 0.1029 - val_accuracy: 0.9718 - lr: 0.0010 - 6s/epoch - 826ms/step
# Epoch 721/800
#
# Epoch 00721: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0298 - accuracy: 0.9916 - val_loss: 0.1297 - val_accuracy: 0.9577 - lr: 0.0010 - 6s/epoch - 837ms/step
# Epoch 722/800
#
# Epoch 00722: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0301 - accuracy: 0.9907 - val_loss: 0.1154 - val_accuracy: 0.9698 - lr: 0.0010 - 6s/epoch - 818ms/step
# Epoch 723/800
#
# Epoch 00723: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0314 - accuracy: 0.9884 - val_loss: 0.1523 - val_accuracy: 0.9598 - lr: 0.0010 - 6s/epoch - 815ms/step
# Epoch 724/800
#
# Epoch 00724: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0373 - accuracy: 0.9884 - val_loss: 0.2262 - val_accuracy: 0.9437 - lr: 0.0010 - 6s/epoch - 823ms/step
# Epoch 725/800
#
# Epoch 00725: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0272 - accuracy: 0.9913 - val_loss: 0.1332 - val_accuracy: 0.9638 - lr: 0.0010 - 6s/epoch - 829ms/step
# Epoch 726/800
#
# Epoch 00726: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0309 - accuracy: 0.9905 - val_loss: 0.1270 - val_accuracy: 0.9638 - lr: 0.0010 - 6s/epoch - 840ms/step
# Epoch 727/800
#
# Epoch 00727: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0320 - accuracy: 0.9890 - val_loss: 0.2010 - val_accuracy: 0.9497 - lr: 0.0010 - 6s/epoch - 831ms/step
# Epoch 728/800
#
# Epoch 00728: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0391 - accuracy: 0.9867 - val_loss: 0.1610 - val_accuracy: 0.9557 - lr: 0.0010 - 6s/epoch - 836ms/step
# Epoch 729/800
#
# Epoch 00729: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0358 - accuracy: 0.9827 - val_loss: 0.1804 - val_accuracy: 0.9557 - lr: 0.0010 - 6s/epoch - 849ms/step
# Epoch 730/800
#
# Epoch 00730: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0236 - accuracy: 0.9916 - val_loss: 0.1517 - val_accuracy: 0.9658 - lr: 0.0010 - 6s/epoch - 853ms/step
# Epoch 731/800
#
# Epoch 00731: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0327 - accuracy: 0.9913 - val_loss: 0.1029 - val_accuracy: 0.9658 - lr: 0.0010 - 6s/epoch - 824ms/step
# Epoch 732/800
#
# Epoch 00732: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0249 - accuracy: 0.9931 - val_loss: 0.1707 - val_accuracy: 0.9598 - lr: 0.0010 - 6s/epoch - 819ms/step
# Epoch 733/800
#
# Epoch 00733: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0359 - accuracy: 0.9873 - val_loss: 0.1605 - val_accuracy: 0.9537 - lr: 0.0010 - 6s/epoch - 824ms/step
# Epoch 734/800
#
# Epoch 00734: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0323 - accuracy: 0.9879 - val_loss: 0.1200 - val_accuracy: 0.9698 - lr: 0.0010 - 6s/epoch - 815ms/step
# Epoch 735/800
#
# Epoch 00735: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0442 - accuracy: 0.9826 - val_loss: 0.1627 - val_accuracy: 0.9598 - lr: 0.0010 - 6s/epoch - 824ms/step
# Epoch 736/800
#
# Epoch 00736: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0368 - accuracy: 0.9890 - val_loss: 0.4952 - val_accuracy: 0.8793 - lr: 0.0010 - 6s/epoch - 814ms/step
# Epoch 737/800
#
# Epoch 00737: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0303 - accuracy: 0.9902 - val_loss: 0.1402 - val_accuracy: 0.9517 - lr: 0.0010 - 6s/epoch - 816ms/step
# Epoch 738/800
#
# Epoch 00738: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0260 - accuracy: 0.9913 - val_loss: 0.1105 - val_accuracy: 0.9678 - lr: 0.0010 - 6s/epoch - 836ms/step
# Epoch 739/800
#
# Epoch 00739: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0303 - accuracy: 0.9884 - val_loss: 0.1647 - val_accuracy: 0.9477 - lr: 0.0010 - 6s/epoch - 836ms/step
# Epoch 740/800
#
# Epoch 00740: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0375 - accuracy: 0.9867 - val_loss: 0.1080 - val_accuracy: 0.9618 - lr: 0.0010 - 6s/epoch - 823ms/step
# Epoch 741/800
#
# Epoch 00741: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0262 - accuracy: 0.9890 - val_loss: 0.2508 - val_accuracy: 0.9276 - lr: 0.0010 - 6s/epoch - 814ms/step
# Epoch 742/800
#
# Epoch 00742: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0265 - accuracy: 0.9896 - val_loss: 0.1633 - val_accuracy: 0.9638 - lr: 0.0010 - 6s/epoch - 824ms/step
# Epoch 743/800
#
# Epoch 00743: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0358 - accuracy: 0.9890 - val_loss: 0.1054 - val_accuracy: 0.9738 - lr: 0.0010 - 6s/epoch - 817ms/step
# Epoch 744/800
#
# Epoch 00744: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0281 - accuracy: 0.9913 - val_loss: 0.1040 - val_accuracy: 0.9678 - lr: 0.0010 - 6s/epoch - 826ms/step
# Epoch 745/800
#
# Epoch 00745: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0320 - accuracy: 0.9884 - val_loss: 0.1422 - val_accuracy: 0.9678 - lr: 0.0010 - 6s/epoch - 805ms/step
# Epoch 746/800
#
# Epoch 00746: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0208 - accuracy: 0.9919 - val_loss: 0.1660 - val_accuracy: 0.9457 - lr: 0.0010 - 6s/epoch - 827ms/step
# Epoch 747/800
#
# Epoch 00747: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0302 - accuracy: 0.9890 - val_loss: 0.1055 - val_accuracy: 0.9738 - lr: 0.0010 - 6s/epoch - 828ms/step
# Epoch 748/800
#
# Epoch 00748: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0334 - accuracy: 0.9907 - val_loss: 0.1795 - val_accuracy: 0.9477 - lr: 0.0010 - 6s/epoch - 823ms/step
# Epoch 749/800
#
# Epoch 00749: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0266 - accuracy: 0.9919 - val_loss: 0.1621 - val_accuracy: 0.9618 - lr: 0.0010 - 6s/epoch - 814ms/step
# Epoch 750/800
#
# Epoch 00750: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0320 - accuracy: 0.9877 - val_loss: 0.2234 - val_accuracy: 0.9356 - lr: 0.0010 - 6s/epoch - 846ms/step
# Epoch 751/800
#
# Epoch 00751: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0259 - accuracy: 0.9907 - val_loss: 0.1455 - val_accuracy: 0.9497 - lr: 0.0010 - 6s/epoch - 836ms/step
# Epoch 752/800
#
# Epoch 00752: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0265 - accuracy: 0.9907 - val_loss: 0.3658 - val_accuracy: 0.9115 - lr: 0.0010 - 6s/epoch - 821ms/step
# Epoch 753/800
#
# Epoch 00753: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0324 - accuracy: 0.9884 - val_loss: 0.1334 - val_accuracy: 0.9577 - lr: 0.0010 - 6s/epoch - 825ms/step
# Epoch 754/800
#
# Epoch 00754: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0476 - accuracy: 0.9838 - val_loss: 0.2218 - val_accuracy: 0.9457 - lr: 0.0010 - 6s/epoch - 837ms/step
# Epoch 755/800
#
# Epoch 00755: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0502 - accuracy: 0.9844 - val_loss: 0.1359 - val_accuracy: 0.9577 - lr: 0.0010 - 6s/epoch - 812ms/step
# Epoch 756/800
#
# Epoch 00756: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0521 - accuracy: 0.9838 - val_loss: 0.1202 - val_accuracy: 0.9698 - lr: 0.0010 - 6s/epoch - 836ms/step
# Epoch 757/800
#
# Epoch 00757: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0519 - accuracy: 0.9838 - val_loss: 0.1186 - val_accuracy: 0.9698 - lr: 0.0010 - 6s/epoch - 841ms/step
# Epoch 758/800
#
# Epoch 00758: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0321 - accuracy: 0.9879 - val_loss: 0.0848 - val_accuracy: 0.9678 - lr: 0.0010 - 6s/epoch - 820ms/step
# Epoch 759/800
#
# Epoch 00759: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0289 - accuracy: 0.9913 - val_loss: 0.0945 - val_accuracy: 0.9638 - lr: 0.0010 - 6s/epoch - 832ms/step
# Epoch 760/800
#
# Epoch 00760: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0285 - accuracy: 0.9890 - val_loss: 0.1276 - val_accuracy: 0.9577 - lr: 0.0010 - 6s/epoch - 819ms/step
# Epoch 761/800
#
# Epoch 00761: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0368 - accuracy: 0.9872 - val_loss: 0.1301 - val_accuracy: 0.9598 - lr: 0.0010 - 6s/epoch - 843ms/step
# Epoch 762/800
#
# Epoch 00762: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0264 - accuracy: 0.9902 - val_loss: 0.1085 - val_accuracy: 0.9638 - lr: 0.0010 - 6s/epoch - 822ms/step
# Epoch 763/800
#
# Epoch 00763: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0333 - accuracy: 0.9894 - val_loss: 0.2445 - val_accuracy: 0.9416 - lr: 0.0010 - 6s/epoch - 840ms/step
# Epoch 764/800
#
# Epoch 00764: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0326 - accuracy: 0.9873 - val_loss: 0.1402 - val_accuracy: 0.9638 - lr: 0.0010 - 6s/epoch - 821ms/step
# Epoch 765/800
#
# Epoch 00765: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0399 - accuracy: 0.9855 - val_loss: 0.1077 - val_accuracy: 0.9618 - lr: 0.0010 - 6s/epoch - 804ms/step
# Epoch 766/800
#
# Epoch 00766: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0363 - accuracy: 0.9902 - val_loss: 0.5073 - val_accuracy: 0.8813 - lr: 0.0010 - 6s/epoch - 814ms/step
# Epoch 767/800
#
# Epoch 00767: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0295 - accuracy: 0.9879 - val_loss: 0.1646 - val_accuracy: 0.9557 - lr: 0.0010 - 6s/epoch - 817ms/step
# Epoch 768/800
#
# Epoch 00768: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0494 - accuracy: 0.9832 - val_loss: 0.2094 - val_accuracy: 0.9376 - lr: 0.0010 - 6s/epoch - 810ms/step
# Epoch 769/800
#
# Epoch 00769: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0463 - accuracy: 0.9855 - val_loss: 0.3717 - val_accuracy: 0.9155 - lr: 0.0010 - 6s/epoch - 822ms/step
# Epoch 770/800
#
# Epoch 00770: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0466 - accuracy: 0.9826 - val_loss: 0.1933 - val_accuracy: 0.9416 - lr: 0.0010 - 6s/epoch - 831ms/step
# Epoch 771/800
#
# Epoch 00771: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0415 - accuracy: 0.9861 - val_loss: 0.1263 - val_accuracy: 0.9638 - lr: 0.0010 - 6s/epoch - 823ms/step
# Epoch 772/800
#
# Epoch 00772: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0458 - accuracy: 0.9827 - val_loss: 0.2695 - val_accuracy: 0.9356 - lr: 0.0010 - 6s/epoch - 844ms/step
# Epoch 773/800
#
# Epoch 00773: val_loss did not improve from 0.08204
# 7/7 - 6s - loss: 0.0528 - accuracy: 0.9849 - val_loss: 0.4532 - val_accuracy: 0.8913 - lr: 0.0010 - 6s/epoch - 841ms/step
# Epoch 774/800
#
# Epoch 00774: val_loss improved from 0.08204 to 0.07150, saving model to /content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5
# 7/7 - 8s - loss: 0.0354 - accuracy: 0.9873 - val_loss: 0.0715 - val_accuracy: 0.9839 - lr: 0.0010 - 8s/epoch - 1s/step
# Epoch 775/800
#
# Epoch 00775: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0302 - accuracy: 0.9884 - val_loss: 0.1586 - val_accuracy: 0.9577 - lr: 0.0010 - 6s/epoch - 827ms/step
# Epoch 776/800
#
# Epoch 00776: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0287 - accuracy: 0.9919 - val_loss: 0.1720 - val_accuracy: 0.9517 - lr: 0.0010 - 6s/epoch - 856ms/step
# Epoch 777/800
#
# Epoch 00777: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0210 - accuracy: 0.9931 - val_loss: 0.1043 - val_accuracy: 0.9718 - lr: 0.0010 - 6s/epoch - 850ms/step
# Epoch 778/800
#
# Epoch 00778: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0274 - accuracy: 0.9913 - val_loss: 0.1420 - val_accuracy: 0.9537 - lr: 0.0010 - 6s/epoch - 830ms/step
# Epoch 779/800
#
# Epoch 00779: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0289 - accuracy: 0.9884 - val_loss: 0.4593 - val_accuracy: 0.8954 - lr: 0.0010 - 6s/epoch - 818ms/step
# Epoch 780/800
#
# Epoch 00780: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0510 - accuracy: 0.9803 - val_loss: 0.2262 - val_accuracy: 0.9477 - lr: 0.0010 - 6s/epoch - 822ms/step
# Epoch 781/800
#
# Epoch 00781: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0237 - accuracy: 0.9919 - val_loss: 0.5724 - val_accuracy: 0.8652 - lr: 0.0010 - 6s/epoch - 808ms/step
# Epoch 782/800
#
# Epoch 00782: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0345 - accuracy: 0.9890 - val_loss: 0.1795 - val_accuracy: 0.9416 - lr: 0.0010 - 6s/epoch - 806ms/step
# Epoch 783/800
#
# Epoch 00783: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0358 - accuracy: 0.9884 - val_loss: 0.1976 - val_accuracy: 0.9497 - lr: 0.0010 - 6s/epoch - 811ms/step
# Epoch 784/800
#
# Epoch 00784: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0392 - accuracy: 0.9873 - val_loss: 0.1736 - val_accuracy: 0.9497 - lr: 0.0010 - 6s/epoch - 829ms/step
# Epoch 785/800
#
# Epoch 00785: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0263 - accuracy: 0.9936 - val_loss: 0.2794 - val_accuracy: 0.9437 - lr: 0.0010 - 6s/epoch - 820ms/step
# Epoch 786/800
#
# Epoch 00786: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0275 - accuracy: 0.9916 - val_loss: 0.1325 - val_accuracy: 0.9638 - lr: 0.0010 - 6s/epoch - 847ms/step
# Epoch 787/800
#
# Epoch 00787: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0274 - accuracy: 0.9907 - val_loss: 0.1923 - val_accuracy: 0.9477 - lr: 0.0010 - 6s/epoch - 826ms/step
# Epoch 788/800
#
# Epoch 00788: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0351 - accuracy: 0.9890 - val_loss: 0.0910 - val_accuracy: 0.9678 - lr: 0.0010 - 6s/epoch - 828ms/step
# Epoch 789/800
#
# Epoch 00789: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0268 - accuracy: 0.9911 - val_loss: 0.1724 - val_accuracy: 0.9457 - lr: 0.0010 - 6s/epoch - 870ms/step
# Epoch 790/800
#
# Epoch 00790: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0281 - accuracy: 0.9911 - val_loss: 0.1767 - val_accuracy: 0.9497 - lr: 0.0010 - 6s/epoch - 867ms/step
# Epoch 791/800
#
# Epoch 00791: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0290 - accuracy: 0.9896 - val_loss: 0.1035 - val_accuracy: 0.9759 - lr: 0.0010 - 6s/epoch - 794ms/step
# Epoch 792/800
#
# Epoch 00792: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0194 - accuracy: 0.9936 - val_loss: 0.1187 - val_accuracy: 0.9638 - lr: 0.0010 - 6s/epoch - 821ms/step
# Epoch 793/800
#
# Epoch 00793: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0192 - accuracy: 0.9942 - val_loss: 0.1001 - val_accuracy: 0.9759 - lr: 0.0010 - 6s/epoch - 798ms/step
# Epoch 794/800
#
# Epoch 00794: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0343 - accuracy: 0.9884 - val_loss: 0.1512 - val_accuracy: 0.9577 - lr: 0.0010 - 6s/epoch - 820ms/step
# Epoch 795/800
#
# Epoch 00795: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0187 - accuracy: 0.9913 - val_loss: 0.1379 - val_accuracy: 0.9598 - lr: 0.0010 - 6s/epoch - 820ms/step
# Epoch 796/800
#
# Epoch 00796: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0345 - accuracy: 0.9884 - val_loss: 0.1328 - val_accuracy: 0.9658 - lr: 0.0010 - 6s/epoch - 810ms/step
# Epoch 797/800
#
# Epoch 00797: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0321 - accuracy: 0.9896 - val_loss: 0.2030 - val_accuracy: 0.9557 - lr: 0.0010 - 6s/epoch - 831ms/step
# Epoch 798/800
#
# Epoch 00798: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0314 - accuracy: 0.9902 - val_loss: 0.1725 - val_accuracy: 0.9557 - lr: 0.0010 - 6s/epoch - 799ms/step
# Epoch 799/800
#
# Epoch 00799: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0259 - accuracy: 0.9925 - val_loss: 0.1372 - val_accuracy: 0.9658 - lr: 0.0010 - 6s/epoch - 825ms/step
# Epoch 800/800
#
# Epoch 00800: val_loss did not improve from 0.07150
# 7/7 - 6s - loss: 0.0377 - accuracy: 0.9867 - val_loss: 0.1189 - val_accuracy: 0.9698 - lr: 0.0010 - 6s/epoch - 816ms/step

# %%
model = load_model('/content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/VGG19_V2.h5')
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 16/16 [==============================] - 1s 27ms/step - loss: 0.0715 - accuracy: 0.9839
# Final Loss: 0.07150034606456757, Final Accuracy: 0.9839034080505371

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Blues, annot=True, fmt='g', square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=25)
ax.set_xlabel('Predicted', fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.savefig('/content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/2.png' , dpi=300)

# %%
TN = cm[0][0]
#print(TN)
FN = cm[1][0]
#print(FN)
TP = cm[1][1]
#print(TP)
FP = cm[0][1]
#print(FP)

# Sensitivity, hit rate, recall, or true positive rate
TPR = TP/(TP+FN)
print(TPR)
# Specificity or true negative rate
TNR = TN/(TN+FP)
print(TNR)
# Precision or positive predictive value
PPV = TP/(TP+FP)
# Negative predictive value
NPV = TN/(TN+FN)
# Fall out or false positive rate
FPR = FP/(FP+TN)
# False negative rate
FNR = FN/(TP+FN)
print(FNR)
# False discovery rate
FDR = FP/(TP+FP)

# Overall accuracy
ACC = (TP+TN)/(TP+FP+FN+TN)
print(ACC)
# Out:
# 0.9866666666666667
# 0.9816176470588235
# 0.013333333333333334
# 0.9839034205231388

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'], color='red', marker = 'o', markevery=20, ms = 20, linewidth = '3.5')
plt.plot(hist.history['val_accuracy'], color='black',marker = 'o', markevery=20, ms = 20, linewidth = '3.5')
plt.title('model accuracy', fontsize=35)
plt.ylabel('Accuracy', fontsize=35)
plt.xlabel('Epoch', fontsize=35)
plt.legend(['train', 'test'], loc='upper left', fontsize=35 )
plt.cm.get_cmap('tab10', 2)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.rcParams["figure.figsize"] = (25,15)
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)
plt.savefig('/content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/3.png', dpi=300)


plt.show()



# accuracy plot 
plt.plot(hist.history['loss'], color='red', marker = 'o', markevery=20, ms = 20, linewidth = '3.5')
plt.plot(hist.history['val_loss'], color='black',marker = 'o', markevery=20, ms = 20, linewidth = '3.5')
plt.title('model loss', fontsize=35)
plt.ylabel('Loss', fontsize=35)
plt.xlabel('Epoch', fontsize=35)
plt.legend(['train', 'test'], loc='upper right', fontsize=35 )
plt.cm.get_cmap('tab10', 2)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.rcParams["figure.figsize"] = (25,15)
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)
plt.savefig('/content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/4.png',  dpi=300)

# %%
from skimage import io
from keras.preprocessing import image
#path='imbalanced/Scratch/Scratch_400.jpg'
img = image.load_img('/content/drive/MyDrive/ML/COVID_19_DATA/COVID/Covid (1010).png', grayscale=False, target_size=(120, 120))
show_img=image.load_img('/content/drive/MyDrive/ML/COVID_19_DATA/COVID/Covid (1010).png', grayscale=False, target_size=(200, 200))
disease_class=['Covid-19','Non Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [9.9998879e-01 1.1149409e-05]
# Prediction: Covid-19

# %%
from sklearn.metrics import confusion_matrix, roc_curve
fpr, tpr, thresholds = roc_curve(Y_true, Y_pred)
plt.figure(figsize=(15, 15))
plt.plot(fpr, tpr, color='green', linewidth=4)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve for our model', fontsize=15)
plt.xlabel('False Positive Rate', fontsize=15)
plt.ylabel('True Positive Rate', fontsize=15)
plt.grid(True)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.savefig('/content/drive/MyDrive/ML/COVID_19_DATA/Images/VGG19_V2/5.png',  dpi=300)
